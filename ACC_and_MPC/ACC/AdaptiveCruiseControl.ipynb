# %% [markdown]
# # Adaptive Cruise Control (ACC)
#
# Safety is critical in autonomous driving. In this task, you will design an optimization based safety-critical controller that enables the vehicle to keep a safe distance to the leading vehicle while trying to reach the desired cruise velocity.
#
# The key of this problem is the tradeoff between the **safety** and **tracking** of desired velocity.

# %% [markdown]
# ## System model
#
# We consider the point mass vehicle model:
#
# $$m \frac{dv}{dt} = F_w,$$
#
# where $m$ is the mass, $v$ is the velocity of the vehicle, and $F_w$ is the traction force. For simplification, we omit other resistances, such as aerodynamic drag.
#
# In the context of adaptive cruise control, let the velocity of leading vehicle be $v_0$. Thus, the distance between the two vehicle $D$ is governed by:
#
# $$\frac{dD}{dt} = v_0 - v.$$
#
# Then we have the dynamics of the system as:
#
# $$
# \frac{d}{dt}\begin{bmatrix} D\\ v \end{bmatrix} = \begin{bmatrix} v_0 - v \\ 0 \end{bmatrix} + \begin{bmatrix} 0\\ \frac{1}{m} \end{bmatrix} F_w.
# $$
#
# We assume $v_0$ is piecewise constant in this task.
#
# Now we introduce the constraints need to be considered in the controller design.

# %% [markdown]
# <div>
# <img src="CBF_car2.png" width="500" align="left"/>
# </div>

# %% [markdown]
# ## Input constraints:
#
# The traction and braking force can not exceed the allowable wheel forces:
#
# $$-c_d g \le \frac{F_w}{m} \le c_a g,$$
#
# where $g$ is the gravity, $c_d$ and $c_a$ are the coefficients that indicates the allowable braking and traction force.
#
#
# ## Soft constraints:
#
# We wish the vehicle to achieve the desired cruise velocity $v_d$:
#
# $$(v - v_d)^2 \rightarrow 0.$$
#
#
# ## Hard constraints:
#
#
# ### Half-speedometer safety constraints
# For ACC, we want to keep a safe distance from the leading vehicle.
#
# We enforce the **half-speedometer** rule [6], such that the minimum distances between two vehicles to be half of the speedometer:
#
# $$D \ge \frac{v}{2},$$
#
# with $D$ in $m$ and $v$ in $km / hr$. For example, if the leading vehicle is traveling at $80km/hr$, the minimum distance should be $40m$.
#
# When we convert the unit to $m$ and $m / s$, we have:
#
# $$D \ge 1.8v.$$
#
# ### $T$-lookahead distance
#
# To ensure safety while approaching the leading vehicle, we want the ego vehicle to always be able to maintain safe distance using the **maximal** braking force. Under maximum braking force, we have the dynamics of the vehicle starting at time $t$ as:
#
# $$
# v(t+\tau)=v(t)-\tau c_d g,
# $$
#
# and thus solving for $T$ such that $v(t+T)=v_0$ (following at the velocity of the lead vehicle) yields
#
# $$
# T=\frac{v_0-v(t)}{-c_d g} .
# $$
#
# Then integrating the dynamics of $D$ yields:
#
# $$
# \begin{aligned}
# D(t+T) & =D(t)+\int_0^T\left[v_0-v(t+\tau)\right] d \tau \\
# & =D(t)+\int_0^T\left[v_0-v(t)+\tau c_d g\right] d \tau \\
# & =D(t)-\frac{1}{2} \frac{\left[v_0-v(t)\right]^2}{c_d g}
# \end{aligned}
# $$
#
# Hence, if the current headway is $D(t)$, the headway looking $T$ seconds ahead, which is based on decelerating at the maximum rate to a following speed of $v_0$, is bounded by
#
# $$
# D(t+T)=D(t)-\frac{1}{2} \frac{\left[v_0-v(t)\right]^2}{c_d g}.
# $$
#
# Finally, we have the safety constraints that ensure the vehicle always maintain the half of the speedometer distance by applying the maximum braking forces:
#
# $$
# D(t+T) = D(t)-\frac{1}{2} \frac{\left[v_0-v(t)\right]^2}{c_d g} \ge 1.8v(t).
# $$

# %% [markdown]
# # Controller design
#
# Our goal is to design a controller that satsify the safety constraints
#
# $$D(t)-\frac{1}{2} \frac{\left[v_0-v(t)\right]^2}{c_d g} \ge 1.8v(t), \forall t > 0,$$
#
# and let the velocity $v$ go as close to $v_d$ as possible within the control limit.
#
# However, we note that the LQR designed in class is equivalent to enforcing an **equality constraint** to ensure convergence to the desired states, which leaves no space for safety. Here we replace the equality constraint with an **inequality constraint**.
#
# ## Linear state feedback
#
# To track the desired velocity, the linear feedback, such as LQR, takes the form:
#
# $F_w = -K(v - v_d)$, where $K \in \mathbb{R}_{+}$ is the gain that decide how fast you can regularize $(v - v_d)$ to 0.
#
# Now we define the tracking performance as the square of the tracking error, i.e.
#
# $$h = \frac{(v - v_d)^2}{2}.$$
#
# Then we take derivative of $h$ with respect to time,
#
# $$
# \begin{equation}
# \begin{aligned}
#
# \dot{h} &= \frac{\partial h}{\partial v} \frac{dv}{dt} \\
#         &= 0 + (v - v_d) \frac{F_w}{m} \\
#         &= - \frac{K(v - v_d)^2}{m} \\
#         &= -\frac{2K}{m}h
#
# \end{aligned}
# \end{equation}
# $$
#
# Thus, solving the ODE, we have:
#
# $$h(t) = \exp{(-\frac{2K}{m} t)} h(0),$$
#
# with $h(0) = \frac{1}{2}(v(0) - v_d)^2$, which gurantees $(v - v_d)^2 \rightarrow 0$, as $t \rightarrow \infty$.
#
# ## Tracking constraint as inequality
#
# To allow the tradeoff for safety constraints, we replace the state feedback by inequality constraints on the tracking error:
#
# Instead of Find $F_w$ to ensure $$\dot{h} = -\lambda h, $$
#
# we only try to find $F_w$ to make $$\dot{h} \le -\lambda h, \text{ for some } \lambda > 0.$$
#
# <!-- we can bound the value of $h$ by manipulating its change rate with respect to time. -->
#
# <!-- By the comparison lemma[4], for a scalar function $h_1(t)$, if there exist another function $h_2(t)$, such that the time derivative $\dot{h}_1(t) \le \dot{h}_2(t)$ and initial value $h_1(0) \le h_2(0)$, we have $0 < h_1(t) \le h_2(t), \forall t$. -->
#
# By the comparison lemma[4], if we can find such $F_w$ for $\forall t\ge 0$, there is an upper bound on the convergence rate of the tracking error:
#
# $${h}(t) \le \exp{(-\lambda t)} h(0),$$
#
# given the initial condition that $h(0)\ge 0 $.
#
# In this case, the upper bound of the tracking error is bounded by ${h}(t) = \exp{(-\lambda t)} h(0)$, which corresponds to a linear state feedback.
#
# ## Safety constraints
#
# Similar to the tracking performance, we define the barrier function to indicate the safety
#
# $$B:= D-\frac{1}{2} \frac{\left[v_0-v\right]^2}{c_d g} - 1.8v.$$
#
# Where $B > 0$ indicate strict satisfaction of the safety constraints.
#
# If we can find $F_w$ to make $\dot{B} \ge -\alpha B$, with $\alpha > 0$,
#
# we have the lower bounds on barrier function if $\exist F_w, \forall t$:
#
# $$
# B(t) \ge \exp{(-\alpha t) B(0)} \ge 0, B(0) \ge 0.
# $$

# %% [markdown]
# ## QP-based minimum norm controller
#
# If we substitute the dynamics of the vehicle to the above two inequality constraints on $h$ and $B$, we have:
#
# $$
# \dot{h} =  \frac{(v - v_d)}{m}F_w \le -\lambda h
# $$
#
# $$
# \begin{equation}
# \begin{aligned}
#     \dot{B} =& \frac{d D}{d t} - \frac{d \frac{\left[v_0-v\right]^2}{2c_d g} + 1.8v}{d v}\frac{d v}{d t} \\
#             =& (v_0 - v) - \frac{1}{m}(1.8 + \frac{v - v_0}{c_dg}) F_w \ge -\alpha B
# \end{aligned}
# \end{equation}
# $$
#
# Thus, a straight forward idea to bridge the **safety** and **tracking** performance is to design a controller that generate the smllest control input while satisfying the two inequality constraints:
#
# $$
# \begin{equation}
#     \begin{aligned}
#     \min_{F_w} & \quad F_w^2 \\
#     \text{s.t. } & \frac{(v - v_d)}{m}F_w \le -\lambda h, \\
#                  & (v_0 - v) - \frac{1}{m}(1.8 + \frac{v - v_0}{c_dg}) F_w \ge -\alpha B, \\
#                  & -c_d g \le \frac{F_w}{m} \le c_a g.
#     \end{aligned}
# \end{equation}
# $$
#
# By solving this QP, we are able to find the minimal-norm control input within the control limits, while trying to converge to the desired velocity, and keep the safe distance.
#
# ### Tackling infeasibility
#
# However, the two inequality may result in empty feasible set for the QP. For example, if the velocity of the leading vehicle is slower than the desired velocity, there is no control input that can enable the velocity converge to the desired one without sacrificing safety.
#
# To solve the problem, we introduce a slack variable $\delta$ that allowing violation of the constraints for velocity tracking. While the safety is the priority, which should be always satisfied:
#
# $$
# \begin{equation}
#     \begin{aligned}
#     \min_{F_w, \delta} & \quad F_w^2 +  {w \delta^2} \\
#     \text{s.t. } & \frac{(v - v_d)}{m}F_w \le -\lambda h + \delta, \\
#                  & (v_0 - v) - \frac{1}{m}(1.8 + \frac{v - v_0}{c_dg}) F_w \ge -\alpha B, \\
#                  & -c_d g \le \frac{F_w}{m} \le c_a g, \\
#                  & \delta \ge 0.
#     \end{aligned}
# \end{equation}
# $$
#
# where $w$ is a large weight that penalize the slack variable.

# %% [markdown]
# ## Submission:
#
# Please fill **Student_Controller()** to compute the required matrix for the implementation of the slacked QP-based minimal norm controller, $P, q, A$ and $b$.
#
# You will need to tune the parameters $\lambda$ for tracking, $\alpha$ for safety constraints and $w$ for the weight of slack variable.
#
# $$
# \begin{equation}
#     \begin{aligned}
#     \min_{x} & \quad \frac{1}{2}x^{T}Px + q^{T}x \\
#     \text{s.t. } & Ax\le b
#     \end{aligned}
# \end{equation}
# $$
#
# Note: $x:= [F_w, \delta]$ and $A \in \mathbb{R}^{5\times 2}$. We will use the first variable produced by the QP solver as the control input.
#
# Hints:
#
# 1. Larger $\lambda$ enables faster tracking of desired speed.
#
# 2. Smaller $\alpha$ enables slower convergence to $B=0$.
#
# 3. $w$ should be a large number.
#
# 4. Ensure the three number are in proper magnitute to make the QP feasible.
#
# ## Requirement:
#
# 1. The safety constraints $B\ge 0$ is satisfied all time before the vehicle changes velocity.
#
# 2. The vehicle reaches the desired speed when it is allowed, e.g., before the leading vehicle changes its velocity or the leading vehicle's velocity is faster than the desired speed.
#
# 3. No collision detected all the time.
#
# 4. Input constraints are not violated.
#
# 5. The QP is always feasible.
#
# ## Remark:
#
# The leading car will change its velocity at the swtich time shown in the **param**.
#
# We will not penalize test cases that is impossible to gurantee safety.
#
# If you are interested, refer to [5] about how to know when it is possible or not to maintain the safety.

# %%
# %load_ext autoreload
# %autoreload 2
from student_controller_acc import *
# from gsi_controller_acc import *
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
param = {"vd": 25.0, "v0": 10.0, "m": 2000, "Cag": 0.3 * 9.81, "Cdg": 0.8 * 9.81, "v01": 10, "v02": 20, "switch_time": 10, "terminal_time": 50}
y0 = np.array([250, 20]) # [D(0), v(0)]
t, B, y, u = sim_vehicle(Student_Controller, param, y0)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 5.208e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 2.924e+14
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 5.208e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 1.180e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 8.139e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 1.541e+14
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 8.139e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 6.931e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 9.743e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
#       warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.24e+04   2.44e+08   1.00e-01   2.14e-05s
#  125   1.5489e+13   5.52e-03   1.79e+03   6.03e+00   4.62e-05s
# plsh   1.5489e+13   6.77e-19   8.81e-11   --------   5.63e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 125
# optimal objective:    15488762405703.9961
# run time:             5.63e-05s
# optimal rho estimate: 3.43e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_in-------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# f = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.56e+04   3.67e+09   1.00e-01   2.63e-05s
#  150   2.9242e+14   1.57e-02   4.58e+03   2.78e+01   4.57e-05s
# plsh   2.9242e+14   0.00e+00   7.70e-09   --------   5.24e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 150
# optimal objective:    292417231982465.8750
# run time:             5.24e-05s
# optimal rho estimate: 3.91e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.13e+04   2.67e+09   1.00e-01   1.91e-05s
#  150   1.5411e+14   2.31e-02   4.09e+02   3.58e+00   4.41e-05s
# plsh   1.5411e+14   0.00e+00   6.41e-10   --------   5.23e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 150
# optimal objective:    154114913825416.2500
# run time:             5.23e-05s
# optimal rho estimate: 1.50e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   7.75e+03   1.82e+09   1.00e-01   4.66e-05s
#  125   7.1861e+13   2.78e-02   9.46e+03   2.47e+00   7.76e-05s
# plsh   7.1861e+13   0.00e+00   6.41e-10   --------   9.39e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 125
# optimal objective:    71861339254300.9219
# run time:             9.39e-05s
# optimal rho (CVXPY) Oct 09 05:58:24 AM: Optimal value: 7.186e+13
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 9.743e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 9.134e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 1.022e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 2.797e+13
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 1.022e-02 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 2.040e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 9.030e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 8.299e+12
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 9.030e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 6.611e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 6.186e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 1.906e+12
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 6.186e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 1.123e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 8.940e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# estimate: 5.48e-01
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   4.84e+03   1.14e+09   1.00e-01   7.82e-05s
#  175   2.7970e+13   5.04e-03   2.68e+02   7.01e+00   1.14e-04s
# plsh   2.7970e+13   0.00e+00   -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# 2.73e-09   --------   1.31e-04s
#
# status:               solved
# solution polish:      successful
# number of iterations: 175
# optimal objective:    27969540873490.5430
# run time:             1.31e-04s
# optimal rho estimate: 1.81e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   2.64e+03   6.20e+08   1.00e-01   2.24e-05s
#  100   8.2991e+12   3.67e-03   5.96e+04   3.40e+00   4.24e-05s
# plsh   8.2991e+12   0.00e+00   1.16e-10   --------   5.16e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 100
# optimal objective:    8299054609394.9941
# run time:             5.16e-05s
# optimal rho estimate: 4.85e-01
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           (CVXPY) Oct 09 05:58:24 AM: Optimal value: 2.927e+11
# sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.26e+03   2.97e+08   1.00e-01   4.70e-05s
#   75   1.9061e+12   4.22e-03   3.66e+03   1.00e+00   6.73e-05s
# plsh   1.9061e+12   0.00e+00   2.46e-10   --------   8.02e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 75
# optimal objective:    1906072067878.3694
# run time:             8.02e-05s
# optimal rho estimate: 1.16e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) +(CVXPY) Oct 09 05:58:24 AM: Compilation took 8.940e-03 seconds
#  nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-(CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 9.563e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 7.056e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 1.834e+10
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 7.056e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 5.848e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 8.173e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 1.363e+08
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 8.173e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 8.655e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 6.541e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   4.96e+02   1.17e+08   1.00e-01   4.56e-05s
#   50   2.9273e+11   1.17e-03   1.50e+03   1.00e+00   6.51e-05s
# plsh   2.9273e+11   0.00e+00   4.99e-11   --------   9.18e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 50
# optimal objective:    292729454762.7339
# run time:             9.18e-05s
# optimal rho estimate: 2.50e-01
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# ---------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# --------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.24e+02   2.92e+07   1.00e-01   2.08e-05s
#   50   1.8341e+10   2.11e-03   2.34e+02   6.24e-01   3.39e-05s
# plsh   1.8341e+10   0.00e+00   6.11e-12   --------   4.35e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 50
# optimal objective:    18341130808.7869
# run time:             4.35e-05s
# optimal rho estimate: 9.86e-01
#
# ---------------------------------------------------(CVXPY) Oct 09 05:58:24 AM: Optimal value: 2.014e+07
# --------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.07e+01   2.51e+06   1.00e-01   4.85e-05s
#   50   1.3623e+08   2.22e-03   1.23e+02   1.00e-01   6.29e-05s
# plsh   1.3628e+08   0.00e+00   0.00e+00   --------   7.28e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 50
# optimal objective:    136279379.0186
# run time:             7.28e-05s
# optimal rho estimate: 6.03e-02
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   4.10e+0(CVXPY) Oct 09 05:58:24 AM: Compilation took 6.541e-03 seconds
# 0   9.64e+05   1.00e-01   1.84e-05s
#   50   2.0124e+07   1.45e-03   3.38e+01   1.00e-01   2.95e-0(CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 5.648e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 7.465e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 7.706e+06
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 7.465e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 1.098e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 6.023e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 4.037e+06
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 6.023e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 1.617e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 7.667e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:24 AM: Optimal value: 2.479e+06
# (CVXPY) Oct 09 05:58:24 AM: Compilation took 7.667e-03 seconds
# (CVXPY) Oct 09 05:58:24 AM: Solver (including time spent in interface) took 8.245e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:24 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:24 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:24 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:24 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:24 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:24 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:24 AM: Finished problem compilation (took 6.741e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Invoking solver OSQP  to obtain a solution.
# 5s
# plsh   2.0138e+07   8.14e-16   1.93e-09   --------   4.18e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 50
# optimal objective:    20137823.2154
# run time:             4.18e-05s
# optimal rho estimate: 9.98e-02
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on-------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:24 AM: Problem status: optimal
# , time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   2.54e+00   5.96e+05   1.00e-01   5.95e-05s
#   75   7.7065e+06   8.74e-06   3.03e+00   1.00e-01   7.87e-05s
# plsh   7.7064e+06   4.07e-16   9.67e-10   --------   8.89e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 75
# optimal objective:    7706443.1356
# run time:             8.89e-05s
# optimal rho estimate: 2.41e-02
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.84e+00   4.31e+05   1.00e-01   1.20e-04s
#   75   4.0374e+06   4.13e-08   1.87e+00   1.00e-01   1.56e-04s
# plsh   4.0374e+06   0.00e+00   9.67e-10   --------   1.90e-04s
#
# status:               solved
# solution polish:      successful
# number of iterations: 75
# optimal objective:    4037358.3312
# run time:             1.90e-04s
# optimal rho estimate: 2.11e-03
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#     (CVXPY) Oct 09 05:58:24 AM: Optimal value: 1.675e+06
#       nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.44e+00   3.38e+05   1.00e-01   3.48e-05s
#   75   2.4785e+06   2.87e-06   1.30e+00   1.00e-01   5.14e-05s
# ...
# optimal rho estimate: 1.62e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           chec(CVXPY) Oct 09 05:58:26 AM: Solver (including time spent in interface) took 5.157e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:26 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# k_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm s(CVXPY) Oct 09 05:58:26 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:26 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:26 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:26 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:26 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:26 AM: Finished problem compilation (took 7.518e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:26 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:26 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:26 AM: Optimal value: 2.530e+14
# (CVXPY) Oct 09 05:58:26 AM: Compilation took 7.518e-03 seconds
# (CVXPY) Oct 09 05:58:26 AM: Solver (including time spent in interface) took 1.178e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:26 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:26 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:26 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:26 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:26 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:26 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:26 AM: Finished problem compilation (took 7.857e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:26 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:26 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:26 AM: Optimal value: 2.542e+14
# (CVXPY) Oct 09 05:58:26 AM: Compilation took 7.857e-03 seconds
# (CVXPY) Oct 09 05:58:26 AM: Solver (including time spent in interface) took 5.078e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:26 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:26 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:26 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:26 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:26 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:26 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:26 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:27 AM: Finished problem compilation (took 6.732e-03 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:27 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------tart: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.45e+04   3.41e+09   1.00e-01   2.27e-05s
#  125   2.5189e+14   6.03e-03   1.21e+04   2.66e+00   4.54e-05s
# plsh   2.5189e+14   0.00e+00   7.58e-09   --------   5.45e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 125
# optimal objective:    251888510096753.9688
# run time:             5.45e-05s
# optimal rho estimate: 1.60e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04
# (CVXPY) Oct 09 05:58:27 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:27 AM: Optimal value: 2.553e+14
# ,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.45e+04   3.41e+09   1.00e-01   9.10e-05s
#  175   2.5305e+14   2.01e-02   1.59e+05   3.49e+00   1.27e-04s
# plsh   2.5305e+14   0.00e+00   7.98e-09   --------   1.37e-04s
#
# status:               solved
# solution polish:      successful
# number of iterations: 175
# optimal objective:    253048173350975.3125
# run time:             1.37e-04s
# optimal rho estimate: 1.23e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.46e+04   3.42e+09   1.00e-01   4.16e-05s
#  150   2.5418e+14   1.92e-02   8.83e+04   6.38e+00   6.28e-05s
# plsh   2.5418e+14   0.00e+00   6.19e-09   --------   7.14e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 150
# optimal objective:    254176869173904.8750
# run time:             7.14e-05s
# optimal rho estimate: 3.39e+00
#
# -----------------------------------------------------------------
#            OSQP v0.6.3  -  Operator Splitting QP Solver
#               (c) Bartolomeo Stellato,  Goran Banjac
#         University of Oxford  -  Stanford University 2021
# -----------------------------------------------------------------
# problem:  variables n = 2, constraints m = 5
#           nnz(P) + nnz(A) = 8
# settings: linear system solver = qdldl,
#           eps_abs = 1.0e-05, eps_rel = 1.0e-05,
#           eps_prim_inf = 1.0e-04, eps_dual_inf = 1.0e-04,
#           rho = 1.00e-01 (adaptive),
#           sigma = 1.00e-06, alpha = 1.60, max_iter = 10000
#           check_termination: on (interval 25),
#           scaling: on, scaled_termination: off
#           warm start: on, polish: on, time_limit: off
#
# iter   objective    pri res    dua res    rho        time
#    1   0.0000e+00   1.46e+04   3.43e+09   1.00e-01   2.15e-05s
#  125   2.5528e+14   6.03e-03   1.16e+04   2.54e+00   4.60e-05s
# plsh   2.5528e+14   0.00e+00   1.26e-08   --------   5.54e-05s
#
# status:               solved
# solution polish:      successful
# number of iterations: 125
# optimal objective:    255275319233063.5625
# run time:             5.54e-05s
# optimal rho estimate: (CVXPY) Oct 09 05:58:27 AM: Compilation took 6.732e-03 seconds
# (CVXPY) Oct 09 05:58:27 AM: Solver (including time spent in interface) took 5.755e-04 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:27 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:27 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:27 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:27 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:27 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:27 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:27 AM: Finished problem compilation (took 1.030e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:27 AM: Invoking solver OSQP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:27 AM: Problem status: optimal
# (CVXPY) Oct 09 05:58:27 AM: Optimal value: 2.563e+14
# (CVXPY) Oct 09 05:58:27 AM: Compilation took 1.030e-02 seconds
# (CVXPY) Oct 09 05:58:27 AM: Solver (including time spent in interface) took 1.014e-03 seconds
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 09 05:58:27 AM: Your problem has 2 variables, 1 constraints, and 0 parameters.
# (CVXPY) Oct 09 05:58:27 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 09 05:58:27 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 09 05:58:27 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 09 05:58:27 AM: Compiling problem (target solver=OSQP).
# (CVXPY) Oct 09 05:58:27 AM: Reduction chain: CvxAttr2Constr -> Qp2SymbolicQp -> QpMatrixStuffing -> OSQP
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction Qp2SymbolicQp
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction QpMatrixStuffing
# (CVXPY) Oct 09 05:58:27 AM: Applying reduction OSQP
# (CVXPY) Oct 09 05:58:27 AM: Finished problem compilation (took 8.789e-03 seconds).
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# $v_{01}$ and $v_{02}$ are the leading car velocity before and after the switch time.
#
# $y_0:= [D(0), v(0)]$ is the initial state.
#
# $v_d$ is the desired velocity.
#
# We will test your controller with varying $v_d$, $v_{01}$, $v_{02}$ and $y_0$.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(20, 3))
plt.plot(t, B, label="Value of Barrier Function")
plt.xlabel('$Time (s)$')
plt.ylabel('$B$')
plt.title('Safety Constraints')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(20, 3))
plt.plot(t, y[:, 0], label="Distance to leading vehicle")
plt.xlabel('$Time (s)$')
plt.ylabel('$m$')
plt.title('vehicle Distance')
plt.legend()
plt.grid()
plt.show()


plt.figure(figsize=(20, 3))
plt.plot(t, y[:, 1], label="Ego vehicle Velocity")
v_lead = t * 0
v_lead[t <= param["switch_time"]] = param["v01"]
v_lead[t >= param["switch_time"]] = param["v02"]
plt.plot(t, v_lead, label="Leading vehicle Velocity")
plt.plot(t, t * 0 + param["vd"], "--", label="Desired Velocity")

plt.xlabel('$Time (s)$')
plt.ylabel('$m.s^{-1}$')
plt.title('vehicleicle velocity')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(20, 3))
plt.plot(t, 0 * t - param["Cdg"], "k--", label="Cag")
plt.plot(t, 0 * t + param["Cag"], "k--", label="Cdg")
plt.plot(t, u / param["m"], label="Normalized Control Input")
plt.xlabel('$Time (s)$')
plt.ylabel('$m.s^{-2}$')
plt.title('Normalized Control Inputs')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Background:
#
# ### Comparison lemma:
#
# The following comparison lemma enable us to convert the linear state feedback to a inequality constraints.
#
# Consider the the scalar differential equation
# $$
# \dot{u}=f(t, u), \quad u\left(t_0\right)=u_0
# $$
# where $f(t, u)$ is continuous in $t$ and locally Lipschitz in $u$, for all $t \geq 0$ and all $u \in J \subset R$. Let $\left[t_0, T\right)$ ( $T$ could be infinity) be the maximal interval of existence of the solution $u(t)$, and suppose $u(t) \in J$ for all $t \in\left[t_0, T\right)$. Let $v(t)$ be a continuous function whose upper right hand derivative $D^{+} v(t)$ satisfies the differential inequality
# $$
# D^{+} v(t) \leq f(t, v(t)), \quad v\left(t_0\right) \leq u_0
# $$
# with $v(t) \in J$ for all $t \in\left[t_0, T\right)$. Then, $v(t) \leq u(t)$ for all $t \in\left[t_0, T\right)$.
#
# **The comparison lemma suggests that you can bound the value of $v(t)$ by bounding its derivative compared to a reference function u(t).**
#
# ### CLF-CBF-QP Algorithm:
#
# The square of the tracking error $h$ is the **control Lyapunov function (CLF)** that specify the **stability**. The function $B$ is the **control barrier function (CBF)** that specify the **safety** in the sense of **forward invariance**. The **CLF-CBF-QP** algorithm bridges the safety and stability via a single QP as we implemented in this task.
#
# For more details about the **CLF-CBF-QP** algorithm and the notion of **safety**, please redfer to the following papers [1-3].
#
#
#
# ## References:
#
# [1] Ames, A.D., Grizzle, J.W. and Tabuada, P., 2014, December. Control barrier function based quadratic programs with application to adaptive cruise control. In 53rd IEEE Conference on Decision and Control (pp. 6271-6278). IEEE.
#
# [2] Ames, A.D., Xu, X., Grizzle, J.W. and Tabuada, P., 2016. Control barrier function based quadratic programs for safety critical systems. IEEE Transactions on Automatic Control, 62(8), pp.3861-3876.
#
# [3] Nguyen, Q. and Sreenath, K., 2016, July. Exponential control barrier functions for enforcing high relative-degree safety-critical constraints. In 2016 American Control Conference (ACC) (pp. 322-328). IEEE.
#
# [4] https://en.wikipedia.org/wiki/Gr%C3%B6nwall%27s_inequality
#
# [5] Bansal, S., Chen, M., Herbert, S. and Tomlin, C.J., 2017, December. Hamilton-jacobi reachability: A brief overview and recent advances. In 2017 IEEE 56th Annual Conference on Decision and Control (CDC) (pp. 2242-2253). IEEE.
#
# [6] Vogel, K., 2003. A comparison of headway and time to collision as safety indicators. Accident analysis & prevention, 35(3), pp.427-433.
